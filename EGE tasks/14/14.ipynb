# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# 47163321

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# 883

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# 16001228

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# f = open('17_1.txt').readlines()
# a = [int(x) for x in f]
# s = []

# for i in range(len(a)-1):
#     if (abs(a[i])%3==0 or abs(a[i+1])%3==0):
#         s.append(a[i]+a[i+1])
# print(len(s), max(s))

# f = open('17_2.txt').readlines()
# a = [int(x) for x in f]
# s = []

# for i in range(len(a)-2):
#     b = sorted([a[i], a[i+1], a[i+2]])
#     if max(b)**2<(b[0]**2+b[1]**2):
#         s.append(sum(b))
# print(len(s), max(s))

# f = open('17_3.txt').readlines()
# a = [int(x) for x in f]
# m = min([x for x in a if len(str(x))==4 and x%10==6 and x>0])
# s = []
# def f(x):
#     if len(str(abs(x)))==4 and abs(x)%10==6: return 1
#     return 0

# for i in range(len(a)-2):
#     if ((f(a[i]) + f(a[i+1]) + f(a[i+2])) == 1) and (a[i]+a[i+1]+a[i+2]<=m):
#         s.append(a[i]+a[i+1]+a[i+2])
# print(len(s), max(s))


# for x in '0123456789ABCDEFGHIJKLMNOPQRSTU'[:23]:
#     a = int(f'7{x}38596', 23)+int(f'14{x}36', 23)+int(f'61{x}7', 23)
#     if a%22==0:
#         print(a//22)
#         break

# for p in range(8, 100):
#     for x in range(p):
#         for y in range(p):
#             if (5+4*p)*(7+6*p) == (x*p**2+y*p+2):
#                 print(y*p+x)
#                 break

# alphabet = sorted(set('0123456789QWERTYUIOPASDFGHJKLZXCVBNM'))
# for p in range(8,36):
#     for x in alphabet[0:p]:
#         for y in alphabet[0:p]:
#             if int('45', p) * int('67', p)==int(x + y + '2', p):
#                 print(int(y+x, p))
#                 break
# def f(x):
#     c=''
#     while x!=0:
#         c+=str(x%4)
#         x=x//4
#     return c[::-1]
# k = 0

# for x in range(32):
#     a = 9*32**0+x*32**1+9*32**2+7*32**3+1*32**4+3*128**0+9*128**1+x*128**2+7*128**3
#     if f(a).count('0')>k:
#         k = f(a).count('0')
#         p = sum(map(int, f(a)))
# print(p)
# Out:
# 117

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
